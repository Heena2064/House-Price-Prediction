# %% [markdown]
# # House Price Prediction
#
# A Machine Learning project that predicts house prices using Linear Regression.

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## 1. Objective
#
# The objective of this project is to build a Machine Learning model that can predict house prices based on different features of a house.
#
# In this project, Linear Regression is used to understand the relationship between house features and their SalePrice.

# %% [markdown]
# ## 2. Dataset
#
# The dataset used for this project is the House Prices dataset.
#
# It contains information about different houses, including features such as lot area, overall condition, year built, basement area, and other property characteristics.
#
# The target variable is `SalePrice`, which represents the sale price of the house.
#
# The dataset contains 2919 rows and 13 columns.

# %%
hpp = pd.read_csv("../data/HousePricePrediction (1).csv")

# %%
hpp
# Out:
#         Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0        0          60       RL     8450    Inside     1Fam            5
# 1        1          20       RL     9600       FR2     1Fam            8
# 2        2          60       RL    11250    Inside     1Fam            5
# 3        3          70       RL     9550    Corner     1Fam            5
# 4        4          60       RL    14260       FR2     1Fam            5
# ...    ...         ...      ...      ...       ...      ...          ...
# 2914  2914         160       RM     1936    Inside    Twnhs            7
# 2915  2915         160       RM     1894    Inside   TwnhsE            5
# 2916  2916          20       RL    20000    Inside     1Fam            7
# 2917  2917          85       RL    10441    Inside     1Fam            5
# 2918  2918          60       RL     9627    Inside     1Fam            5
#
#       YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# ...

# %% [markdown]
# ## 3. Features Used
#
# The following numerical features were used as input variables for the Linear Regression model:
#
# - `MSSubClass`
# - `LotArea`
# - `OverallCond`
# - `YearBuilt`
# - `YearRemodAdd`
# - `BsmtFinSF2`
# - `TotalBsmtSF`
#
# The `Id` column was removed because it is only an identifier and does not provide useful information for predicting house prices.
#
# Categorical columns were also removed for this first draft model because Linear Regression requires numerical input.

# %% [markdown]
# ## 4. Target Variable
#
# The target variable for this project is `SalePrice`.
#
# `SalePrice` represents the actual selling price of each house. The Linear Regression model uses the selected house features to predict this value.

# %% [markdown]
# ## 5. Data Preparation
#
# The dataset was inspected to understand its structure, data types, and missing values.
#
# For the first draft model, the first 1460 rows containing `SalePrice` were used.
#
# The `Id` column was removed because it is only an identifier. Categorical columns such as `MSZoning`, `LotConfig`, `BldgType`, and `Exterior1st` were also removed because this first model uses only numerical features.
#
# The data was then divided into input features (`X`) and the target variable (`y`).

# %%
X = hpp.drop(columns=["Id", "MSZoning", "LotConfig", "BldgType", "Exterior1st", "SalePrice"])
y = hpp["SalePrice"]

# %%
hpp_train = hpp.iloc[:1460]

X = hpp_train.drop(columns=["Id", "MSZoning", "LotConfig", "BldgType", "Exterior1st", "SalePrice"])
y = hpp_train["SalePrice"]

# %%
X.shape
y.shape
# Out:
# (1460,)

# %% [markdown]
# ## 6. Train-Test Split
#
# The dataset was divided into training and testing sets using an 80:20 ratio.
#
# - 80% of the data was used for training the model.
# - 20% of the data was used for testing the model.
# - `random_state=42` was used to make the split reproducible.
#
# The training set contains 1168 observations, while the testing set contains 292 observations.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,Y,test_size = 0.2, random_state = 42
)

# %%
X_test.head()
# Out:
#       MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF2  \
# 892           20     8414            8       1963          2003         0.0
# 1105          60    12256            5       1994          1995         0.0
# 413           30     8960            6       1927          1950         0.0
# 522           50     5000            7       1947          1950         0.0
# 1036          20    12898            5       2007          2008         0.0
#
#       TotalBsmtSF
# 892        1059.0
# 1105       1463.0
# 413        1008.0
# 522        1004.0
# 1036       1620.0

# %% [markdown]
# ## 7. Model Used
#
# Linear Regression was used as the first Machine Learning model for this project.
#
# The model was trained using the training data and then used to predict house prices for the test data.

# %%
#model training
from sklearn.linear_model import LinearRegression

#make model by call function
model = LinearRegression()

#for training we willl fit the model and passes values 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#use this model for predictions
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([202471.14355514, 233382.55759054, 120266.43362241, 134204.44870426,
#        263068.97913763, 127534.41848927, 186507.12324987, 157497.16021453,
#        124665.35715052, 142549.68757674, 113602.16038019, 150911.51331302,
#        115722.10826879, 247093.72450427, 197055.4906725 , 190241.49041048,
#        197019.83109241, 188968.62105331, 109914.72602716, 241461.05736522,
#        170143.89260832, 198514.5752892 , 191443.05920784, 172983.7426645 ,
#        232049.74048997, 209502.53238224, 237098.60871826, 130536.13466836,
#        196755.87601707, 236792.84966334, 118034.16570067, 210712.60491946,
#        214975.86018618, 143620.72167937, 261608.75931387, 165715.80033828,
#        157273.32135057, 196877.26709616, 235620.91552785,  67178.32603341,
#        108274.0171945 , 197848.04662168, 149886.46748084, 295360.88104409,
#        144131.23253388,  83427.02077039, 127865.67814164, 157855.59801492,
# ...

# %% [markdown]
# ## 8. Evaluation Results
#
# The model was evaluated using four metrics:
#
# - **MAE (Mean Absolute Error):** 37,871.43
# - **MSE (Mean Squared Error):** 3,259,194,958.46
# - **RMSE (Root Mean Squared Error):** 57,089.36
# - **R² Score:** 0.5751
#
# The R² score indicates that the model explains approximately 57.5% of the variation in house prices.

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("r-squared : ",r2)

n = X_test.shape[0]
p = X_test.shape[1]

adjusted_r2 = 1- ((1-r2)*(n-1)/ (n-p-1))
print("adjusted_r2 : ",adjusted_r2)
# Out:
# r-squared :  0.5750904367788159
# adjusted_r2 :  0.564617313741674

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 37871.42885084627

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
# Out:
# MSE: 3259194958.4598827

# %%
import numpy as np

rmse = np.sqrt(mse)
# Out:
# RMSE: 57089.35941539266

# %% [markdown]
# ## 9. Improved Model - Feature Preprocessing

# %%
X2 = hpp_train[[
    "MSSubClass",
    "MSZoning",
    "LotArea",
    "LotConfig",
    "BldgType",
    "OverallCond",
    "YearBuilt",
    "YearRemodAdd",
    "Exterior1st",
    "BsmtFinSF2",
    "TotalBsmtSF"
]]

y2 = hpp_train["SalePrice"]

# %%
X2.shape
# Out:
# (1460, 11)

# %%
X2.select_dtypes(include="object").columns
# Out:
# Index(['MSZoning', 'LotConfig', 'BldgType', 'Exterior1st'], dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder

X2 = pd.get_dummies(X2, drop_first=True)

# %%
X2.shape
# Out:
# (1460, 33)

# %%
X2.isnull().sum()
# Out:
# MSSubClass             0
# LotArea                0
# OverallCond            0
# YearBuilt              0
# YearRemodAdd           0
# BsmtFinSF2             0
# TotalBsmtSF            0
# MSZoning_FV            0
# MSZoning_RH            0
# MSZoning_RL            0
# MSZoning_RM            0
# LotConfig_CulDSac      0
# LotConfig_FR2          0
# LotConfig_FR3          0
# LotConfig_Inside       0
# BldgType_2fmCon        0
# BldgType_Duplex        0
# BldgType_Twnhs         0
# BldgType_TwnhsE        0
# Exterior1st_AsphShn    0
# Exterior1st_BrkComm    0
# Exterior1st_BrkFace    0
# Exterior1st_CBlock     0
# Exterior1st_CemntBd    0
# Exterior1st_HdBoard    0
# Exterior1st_ImStucc    0
# Exterior1st_MetalSd    0
# Exterior1st_Plywood    0
# Exterior1st_Stone      0
# Exterior1st_Stucco     0
# Exterior1st_VinylSd    0
# Exterior1st_Wd Sdng    0
# Exterior1st_WdShing    0
# dtype: int64

# %%
y2.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 10. Train-Test Split for Improved Model

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, y2, test_size=0.2, random_state=42
)

# %% [markdown]
# ## 11. Improved Linear Regression Model

# %%
model2 = LinearRegression()

model2.fit(X2_train, y2_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 12. Predictions and Evaluation

# %%
y2_pred = model2.predict(X2_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae2 = mean_absolute_error(y2_test, y2_pred)
mse2 = mean_squared_error(y2_test, y2_pred)
rmse2 = np.sqrt(mse2)
r2_2 = r2_score(y2_test, y2_pred)

print("MAE:", mae2)
print("MSE:", mse2)
print("RMSE:", rmse2)
print("R²:", r2_2)
# Out:
# MAE: 34122.85443215004
# MSE: 2918458029.585536
# RMSE: 54022.75473895732
# R²: 0.6195131796544807

# %% [markdown]
# ## 13. Model Comparison
#
# The baseline Linear Regression model achieved an R² score of 0.5751.
#
# After including the categorical features using one-hot encoding, the improved model achieved an R² score of 0.6195.
#
# The improved model also had lower MAE, MSE, and RMSE values than the baseline model.
#
# Therefore, Model 2 performed better than the baseline Model 1.

# %% [markdown]
# ## 14. Conclusion
#
# A Linear Regression model was successfully developed to predict house prices using the given house features.
#
# The baseline model achieved an R² score of 0.5751. After preprocessing the categorical features using one-hot encoding, the improved model achieved an R² score of 0.6195.
#
# The improved model also achieved lower MAE and RMSE values compared to the baseline model. Therefore, including the categorical features improved the performance of the Linear Regression model.
#
# This project demonstrates how data preprocessing and feature representation can improve the performance of a Machine Learning regression model.
